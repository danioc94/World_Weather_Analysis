# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests
import os
import sys

# getting the name of the directory
# where the this file is present.
current = os.path.dirname(os.path.realpath('../World_Weather_Analysis'))
  
# Getting the parent directory name
# where the current directory is present.
parent = os.path.dirname(current)
  
# adding the parent directory to 
# the sys.path.
sys.path.append(parent)

# Import the API key.
from World_Weather_Analysis.config import weather_api_key

#Import citipy module
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | shingu
# Processing Record 4 of Set 1 | the valley
# Processing Record 5 of Set 1 | honolulu
# Processing Record 6 of Set 1 | imbituba
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | nome
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | hami
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | rongcheng
# Processing Record 14 of Set 1 | padang
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | papetoai
# Processing Record 17 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | sierra vista
# Processing Record 20 of Set 1 | port alfred
# Processing Record 21 of Set 1 | san cristobal
# Processing Record 22 of Set 1 | sitka
# Processing Record 23 of Set 1 | pisco
# Processing Record 24 of Set 1 | kahului
# Processing Record 25 of Set 1 | vila velha
# Processing Record 26 of Set 1 | cherskiy
# Processing Record 27 of Set 1 | singkang
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | lorengau
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | mayo
# Processing Record 37 of Set 1 | skibbereen
# Processing Record 38 of Set 1 | lugo
# Processing Record 39 of Set 1 | peru
# Processing Record 40 of Set 1 | fasa
# Processing Record 41 of Set 1 | cedar city
# Processing Record 42 of Set 1 | hofn
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | avarua
# Processing Record 46 of Set 1 | buin
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | coahuayana
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | ixtapa
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | port blair
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | longhua
# Processing Record 7 of Set 2 | ambovombe
# Processing Record 8 of Set 2 | coihaique
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | melton
# Processing Record 11 of Set 2 | airai
# Processing Record 12 of Set 2 | mandalgovi
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | samarinda
# Processing Record 15 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 2 | am timan
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | qaqortoq
# Processing Record 19 of Set 2 | tuatapere
# Processing Record 20 of Set 2 | khandyga
# Processing Record 21 of Set 2 | vardo
# Processing Record 22 of Set 2 | mecca
# Processing Record 23 of Set 2 | port-cartier
# Processing Record 24 of Set 2 | ambilobe
# Processing Record 25 of Set 2 | asau
# Processing Record 26 of Set 2 | zhangye
# Processing Record 27 of Set 2 | dikson
# Processing Record 28 of Set 2 | asfi
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | vilcun
# Processing Record 32 of Set 2 | melo
# Processing Record 33 of Set 2 | muros
# Processing Record 34 of Set 2 | liptovsky hradok
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | hovd
# Processing Record 37 of Set 2 | fort nelson
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | jay
# Processing Record 41 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | odweyne
# Processing Record 44 of Set 2 | coxim
# Processing Record 45 of Set 2 | butaritari
# Processing Record 46 of Set 2 | terrace
# Processing Record 47 of Set 2 | vostok
# Processing Record 48 of Set 2 | sao jose da coroa grande
# Processing Record 49 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 2 | klaksvik
# Processing Record 1 of Set 3 | berlevag
# Processing Record 2 of Set 3 | esperance
# Processing Record 3 of Set 3 | bonthe
# Processing Record 4 of Set 3 | mogadishu
# Processing Record 5 of Set 3 | verkhoyansk
# Processing Record 6 of Set 3 | beringovskiy
# Processing Record 7 of Set 3 | dongfeng
# Processing Record 8 of Set 3 | batagay-alyta
# Processing Record 9 of Set 3 | wahpeton
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | lexington
# Processing Record 12 of Set 3 | narsaq
# Processing Record 13 of Set 3 | saint-francois
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | basco
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | ahipara
# Processing Record 18 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 3 | otjimbingwe
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | daru
# Processing Record 22 of Set 3 | inirida
# Processing Record 23 of Set 3 | andenes
# Processing Record 24 of Set 3 | sung noen
# Processing Record 25 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 3 | lagos
# Processing Record 27 of Set 3 | kushmurun
# Processing Record 28 of Set 3 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | saskylakh
# Processing Record 31 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 3 | vaini
# Processing Record 33 of Set 3 | nantucket
# Processing Record 34 of Set 3 | shancheng
# Processing Record 35 of Set 3 | myszkow
# Processing Record 36 of Set 3 | yerbogachen
# Processing Record 37 of Set 3 | sunagawa
# Processing Record 38 of Set 3 | constitucion
# Processing Record 39 of Set 3 | zhigansk
# Processing Record 40 of Set 3 | poum
# Processing Record 41 of Set 3 | rocha
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | ust-omchug
# Processing Record 44 of Set 3 | olovyannaya
# Processing Record 45 of Set 3 | hobyo
# Processing Record 46 of Set 3 | gizo
# Processing Record 47 of Set 3 | algiers
# Processing Record 48 of Set 3 | tynda
# Processing Record 49 of Set 3 | brae
# Processing Record 50 of Set 3 | leningradskiy
# Processing Record 1 of Set 4 | acapulco
# Processing Record 2 of Set 4 | karratha
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | puerto ayacucho
# Processing Record 6 of Set 4 | pimentel
# Processing Record 7 of Set 4 | tashla
# Processing Record 8 of Set 4 | rio grande
# Processing Record 9 of Set 4 | wukari
# Processing Record 10 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | mikkeli
# Processing Record 13 of Set 4 | saquena
# Processing Record 14 of Set 4 | arraial do cabo
# Processing Record 15 of Set 4 | anadyr
# Processing Record 16 of Set 4 | zonguldak
# Processing Record 17 of Set 4 | golden gate
# Processing Record 18 of Set 4 | kamiiso
# Processing Record 19 of Set 4 | morwa
# Processing Record 20 of Set 4 | camana
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | zeya
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | bay roberts
# Processing Record 25 of Set 4 | mikuni
# Processing Record 26 of Set 4 | sao filipe
# Processing Record 27 of Set 4 | qaanaaq
# Processing Record 28 of Set 4 | tasiilaq
# Processing Record 29 of Set 4 | benjamin aceval
# Processing Record 30 of Set 4 | nacogdoches
# Processing Record 31 of Set 4 | leshukonskoye
# Processing Record 32 of Set 4 | carnarvon
# Processing Record 33 of Set 4 | barrow
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | longyearbyen
# Processing Record 36 of Set 4 | simpang
# Processing Record 37 of Set 4 | coria
# Processing Record 38 of Set 4 | roebourne
# Processing Record 39 of Set 4 | sindhnur
# Processing Record 40 of Set 4 | ojinaga
# Processing Record 41 of Set 4 | kapit
# Processing Record 42 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 4 | toungoo
# City not found. Skipping...
# Processing Record 44 of Set 4 | wageningen
# Processing Record 45 of Set 4 | bowen
# Processing Record 46 of Set 4 | antofagasta
# Processing Record 47 of Set 4 | aklavik
# Processing Record 48 of Set 4 | okato
# Processing Record 49 of Set 4 | paramonga
# Processing Record 50 of Set 4 | mahebourg
# Processing Record 1 of Set 5 | saint-georges
# Processing Record 2 of Set 5 | hatillo
# Processing Record 3 of Set 5 | kropotkin
# Processing Record 4 of Set 5 | nyurba
# Processing Record 5 of Set 5 | amga
# Processing Record 6 of Set 5 | paamiut
# Processing Record 7 of Set 5 | tautira
# Processing Record 8 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 5 | port lincoln
# Processing Record 10 of Set 5 | praia
# Processing Record 11 of Set 5 | bichena
# Processing Record 12 of Set 5 | kavaratti
# Processing Record 13 of Set 5 | biak
# Processing Record 14 of Set 5 | karpathos
# Processing Record 15 of Set 5 | aalen
# Processing Record 16 of Set 5 | thompson
# Processing Record 17 of Set 5 | porto novo
# Processing Record 18 of Set 5 | suining
# Processing Record 19 of Set 5 | kodiak
# Processing Record 20 of Set 5 | san carlos de bariloche
# Processing Record 21 of Set 5 | termini imerese
# Processing Record 22 of Set 5 | souillac
# Processing Record 23 of Set 5 | jalu
# Processing Record 24 of Set 5 | baghdad
# Processing Record 25 of Set 5 | coquimbo
# Processing Record 26 of Set 5 | shellbrook
# Processing Record 27 of Set 5 | olafsvik
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | novonukutskiy
# Processing Record 30 of Set 5 | chimbote
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | burica
# City not found. Skipping...
# Processing Record 33 of Set 5 | yellowknife
# Processing Record 34 of Set 5 | minudasht
# Processing Record 35 of Set 5 | pevek
# Processing Record 36 of Set 5 | labrea
# Processing Record 37 of Set 5 | garmsar
# Processing Record 38 of Set 5 | poya
# Processing Record 39 of Set 5 | sao joao da barra
# Processing Record 40 of Set 5 | new norfolk
# Processing Record 41 of Set 5 | cockburn town
# Processing Record 42 of Set 5 | shyryayeve
# Processing Record 43 of Set 5 | lubumbashi
# Processing Record 44 of Set 5 | faya
# Processing Record 45 of Set 5 | north bend
# Processing Record 46 of Set 5 | minna
# Processing Record 47 of Set 5 | mairang
# Processing Record 48 of Set 5 | lusambo
# Processing Record 49 of Set 5 | kloulklubed
# Processing Record 50 of Set 5 | la sarre
# Processing Record 1 of Set 6 | bethel
# Processing Record 2 of Set 6 | bandarbeyla
# Processing Record 3 of Set 6 | honningsvag
# Processing Record 4 of Set 6 | port hedland
# Processing Record 5 of Set 6 | betioky
# Processing Record 6 of Set 6 | itarema
# Processing Record 7 of Set 6 | jurado
# Processing Record 8 of Set 6 | margate
# Processing Record 9 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 6 | harper
# Processing Record 11 of Set 6 | kaitangata
# Processing Record 12 of Set 6 | myaundzha
# Processing Record 13 of Set 6 | te anau
# Processing Record 14 of Set 6 | srednekolymsk
# Processing Record 15 of Set 6 | mariakani
# Processing Record 16 of Set 6 | port augusta
# Processing Record 17 of Set 6 | nouadhibou
# Processing Record 18 of Set 6 | torbay
# Processing Record 19 of Set 6 | ilulissat
# Processing Record 20 of Set 6 | husavik
# Processing Record 21 of Set 6 | jiuquan
# Processing Record 22 of Set 6 | secunda
# Processing Record 23 of Set 6 | vila
# Processing Record 24 of Set 6 | bathsheba
# Processing Record 25 of Set 6 | loreto
# Processing Record 26 of Set 6 | burnley
# Processing Record 27 of Set 6 | tilichiki
# Processing Record 28 of Set 6 | basavakalyan
# Processing Record 29 of Set 6 | smolenka
# Processing Record 30 of Set 6 | manta
# Processing Record 31 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 6 | sao miguel do iguacu
# Processing Record 33 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 34 of Set 6 | mount gambier
# Processing Record 35 of Set 6 | clyde river
# Processing Record 36 of Set 6 | estelle
# Processing Record 37 of Set 6 | pangkalanbuun
# Processing Record 38 of Set 6 | mitsamiouli
# Processing Record 39 of Set 6 | talnakh
# Processing Record 40 of Set 6 | xining
# Processing Record 41 of Set 6 | puerto palomas
# Processing Record 42 of Set 6 | taltal
# Processing Record 43 of Set 6 | we
# City not found. Skipping...
# Processing Record 44 of Set 6 | kirakira
# Processing Record 45 of Set 6 | homer
# Processing Record 46 of Set 6 | kaili
# Processing Record 47 of Set 6 | batagay
# Processing Record 48 of Set 6 | camacha
# Processing Record 49 of Set 6 | manoel urbano
# Processing Record 50 of Set 6 | meulaboh
# Processing Record 1 of Set 7 | jumla
# Processing Record 2 of Set 7 | kruisfontein
# Processing Record 3 of Set 7 | boa vista
# Processing Record 4 of Set 7 | komsomolskiy
# Processing Record 5 of Set 7 | dunedin
# Processing Record 6 of Set 7 | hamilton
# Processing Record 7 of Set 7 | caravelas
# Processing Record 8 of Set 7 | kerema
# Processing Record 9 of Set 7 | otorohanga
# Processing Record 10 of Set 7 | college
# Processing Record 11 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 7 | thunder bay
# Processing Record 13 of Set 7 | nijar
# Processing Record 14 of Set 7 | misratah
# Processing Record 15 of Set 7 | andradina
# Processing Record 16 of Set 7 | kenmare
# Processing Record 17 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 18 of Set 7 | spas-demensk
# Processing Record 19 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 20 of Set 7 | cabo san lucas
# Processing Record 21 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 22 of Set 7 | nakambala
# Processing Record 23 of Set 7 | tiznit
# Processing Record 24 of Set 7 | mirnyy
# Processing Record 25 of Set 7 | san policarpo
# Processing Record 26 of Set 7 | portland
# Processing Record 27 of Set 7 | altay
# Processing Record 28 of Set 7 | necochea
# Processing Record 29 of Set 7 | sioux lookout
# Processing Record 30 of Set 7 | isangel
# Processing Record 31 of Set 7 | lebu
# Processing Record 32 of Set 7 | balabac
# Processing Record 33 of Set 7 | choma
# Processing Record 34 of Set 7 | krasnogorsk
# Processing Record 35 of Set 7 | ucluelet
# Processing Record 36 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 7 | gat
# Processing Record 38 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 39 of Set 7 | bandar
# Processing Record 40 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 41 of Set 7 | ostrovnoy
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | fairbanks
# Processing Record 44 of Set 7 | lompoc
# Processing Record 45 of Set 7 | bremerton
# Processing Record 46 of Set 7 | acari
# Processing Record 47 of Set 7 | port pirie
# Processing Record 48 of Set 7 | saint-pierre
# Processing Record 49 of Set 7 | chara
# Processing Record 50 of Set 7 | thai binh
# Processing Record 1 of Set 8 | san patricio
# Processing Record 2 of Set 8 | thinadhoo
# Processing Record 3 of Set 8 | guerrero negro
# Processing Record 4 of Set 8 | beni suef
# Processing Record 5 of Set 8 | lavrentiya
# Processing Record 6 of Set 8 | livingston
# Processing Record 7 of Set 8 | cuyo
# Processing Record 8 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 8 | umm kaddadah
# Processing Record 10 of Set 8 | kamenka
# Processing Record 11 of Set 8 | ugoofaaru
# Processing Record 12 of Set 8 | abha
# Processing Record 13 of Set 8 | mersing
# Processing Record 14 of Set 8 | atar
# Processing Record 15 of Set 8 | qasigiannguit
# Processing Record 16 of Set 8 | paramithia
# City not found. Skipping...
# Processing Record 17 of Set 8 | gazojak
# Processing Record 18 of Set 8 | makakilo city
# Processing Record 19 of Set 8 | bima
# Processing Record 20 of Set 8 | raudeberg
# Processing Record 21 of Set 8 | chapais
# Processing Record 22 of Set 8 | broome
# Processing Record 23 of Set 8 | klyuchi
# Processing Record 24 of Set 8 | russell
# Processing Record 25 of Set 8 | batemans bay
# Processing Record 26 of Set 8 | cidreira
# Processing Record 27 of Set 8 | grootfontein
# Processing Record 28 of Set 8 | gorkovskoye
# City not found. Skipping...
# Processing Record 29 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 8 | ancud
# Processing Record 31 of Set 8 | general teran
# Processing Record 32 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 8 | benjamin constant
# Processing Record 34 of Set 8 | sidney
# Processing Record 35 of Set 8 | nakatsugawa
# Processing Record 36 of Set 8 | cheney
# Processing Record 37 of Set 8 | sinnamary
# Processing Record 38 of Set 8 | severo-kurilsk
# Processing Record 39 of Set 8 | choya
# Processing Record 40 of Set 8 | poronaysk
# Processing Record 41 of Set 8 | haines junction
# Processing Record 42 of Set 8 | rawson
# Processing Record 43 of Set 8 | shihezi
# Processing Record 44 of Set 8 | naze
# Processing Record 45 of Set 8 | kieta
# Processing Record 46 of Set 8 | nelson bay
# Processing Record 47 of Set 8 | sakakah
# Processing Record 48 of Set 8 | hasaki
# Processing Record 49 of Set 8 | ciudad bolivar
# Processing Record 50 of Set 8 | kraslava
# Processing Record 1 of Set 9 | eyl
# Processing Record 2 of Set 9 | kaeo
# Processing Record 3 of Set 9 | slave lake
# Processing Record 4 of Set 9 | constantine
# Processing Record 5 of Set 9 | puerto baquerizo moreno
# Processing Record 6 of Set 9 | jawhar
# Processing Record 7 of Set 9 | mitchell
# Processing Record 8 of Set 9 | sabha
# Processing Record 9 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 9 | khasan
# Processing Record 11 of Set 9 | ust-nera
# Processing Record 12 of Set 9 | brasilia
# Processing Record 13 of Set 9 | nemuro
# Processing Record 14 of Set 9 | tutoia
# Processing Record 15 of Set 9 | sohag
# Processing Record 16 of Set 9 | naryan-mar
# Processing Record 17 of Set 9 | arandis
# Processing Record 18 of Set 9 | erdemli
# Processing Record 19 of Set 9 | pangody
# Processing Record 20 of Set 9 | colquechaca
# Processing Record 21 of Set 9 | awbari
# Processing Record 22 of Set 9 | port-gentil
# Processing Record 23 of Set 9 | henties bay
# Processing Record 24 of Set 9 | oktyabrskoye
# Processing Record 25 of Set 9 | nevsehir
# Processing Record 26 of Set 9 | gorgan
# Processing Record 27 of Set 9 | barstow
# Processing Record 28 of Set 9 | pierre
# Processing Record 29 of Set 9 | rudnya
# Processing Record 30 of Set 9 | vyartsilya
# Processing Record 31 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 9 | malanje
# Processing Record 33 of Set 9 | honiara
# Processing Record 34 of Set 9 | kirkuk
# Processing Record 35 of Set 9 | mount isa
# Processing Record 36 of Set 9 | ngunguru
# Processing Record 37 of Set 9 | geraldton
# Processing Record 38 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 39 of Set 9 | innisfail
# Processing Record 40 of Set 9 | khvastovichi
# Processing Record 41 of Set 9 | goderich
# Processing Record 42 of Set 9 | iida
# Processing Record 43 of Set 9 | maragogi
# Processing Record 44 of Set 9 | golden
# Processing Record 45 of Set 9 | pine bluff
# Processing Record 46 of Set 9 | ewa beach
# Processing Record 47 of Set 9 | havre-saint-pierre
# Processing Record 48 of Set 9 | saint george
# Processing Record 49 of Set 9 | turkmenabat
# Processing Record 50 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 10 | shitanjing
# Processing Record 2 of Set 10 | saiki
# Processing Record 3 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 10 | turan
# Processing Record 5 of Set 10 | douglas
# Processing Record 6 of Set 10 | syracuse
# Processing Record 7 of Set 10 | mancio lima
# Processing Record 8 of Set 10 | voi
# Processing Record 9 of Set 10 | salina cruz
# Processing Record 10 of Set 10 | carbonia
# Processing Record 11 of Set 10 | kathmandu
# Processing Record 12 of Set 10 | nang rong
# Processing Record 13 of Set 10 | roald
# Processing Record 14 of Set 10 | aldan
# Processing Record 15 of Set 10 | tucupita
# Processing Record 16 of Set 10 | solnechnyy
# Processing Record 17 of Set 10 | la ronge
# Processing Record 18 of Set 10 | sorland
# Processing Record 19 of Set 10 | leopold
# Processing Record 20 of Set 10 | bangkalan
# Processing Record 21 of Set 10 | evensk
# Processing Record 22 of Set 10 | chakan
# Processing Record 23 of Set 10 | khunti
# Processing Record 24 of Set 10 | santa cruz del sur
# Processing Record 25 of Set 10 | tateyama
# Processing Record 26 of Set 10 | gillette
# Processing Record 27 of Set 10 | kurumkan
# Processing Record 28 of Set 10 | key west
# Processing Record 29 of Set 10 | bam
# Processing Record 30 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 31 of Set 10 | kota belud
# Processing Record 32 of Set 10 | talara
# Processing Record 33 of Set 10 | taiyuan
# Processing Record 34 of Set 10 | kalmunai
# Processing Record 35 of Set 10 | pedernales
# Processing Record 36 of Set 10 | fare
# Processing Record 37 of Set 10 | lata
# Processing Record 38 of Set 10 | gouyave
# Processing Record 39 of Set 10 | eenhana
# Processing Record 40 of Set 10 | sangar
# Processing Record 41 of Set 10 | iracoubo
# Processing Record 42 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 10 | savalou
# Processing Record 44 of Set 10 | waitati
# Processing Record 45 of Set 10 | zalantun
# Processing Record 46 of Set 10 | dali
# Processing Record 47 of Set 10 | seoul
# Processing Record 48 of Set 10 | burgeo
# Processing Record 49 of Set 10 | oranjemund
# Processing Record 50 of Set 10 | kyra
# Processing Record 1 of Set 11 | touros
# Processing Record 2 of Set 11 | khorixas
# Processing Record 3 of Set 11 | riyadh
# Processing Record 4 of Set 11 | bannu
# Processing Record 5 of Set 11 | svetlogorsk
# Processing Record 6 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 11 | kununurra
# Processing Record 9 of Set 11 | saquarema
# Processing Record 10 of Set 11 | coari
# Processing Record 11 of Set 11 | belyy yar
# Processing Record 12 of Set 11 | tura
# Processing Record 13 of Set 11 | zdvinsk
# Processing Record 14 of Set 11 | marsh harbour
# Processing Record 15 of Set 11 | salalah
# Processing Record 16 of Set 11 | san jose
# Processing Record 17 of Set 11 | muroto
# Processing Record 18 of Set 11 | vilyuysk
# Processing Record 19 of Set 11 | udachnyy
# Processing Record 20 of Set 11 | brownsville
# Processing Record 21 of Set 11 | kochi
# Processing Record 22 of Set 11 | richard toll
# City not found. Skipping...
# Processing Record 23 of Set 11 | acurenam
# Processing Record 24 of Set 11 | koping
# Processing Record 25 of Set 11 | vanavara
# Processing Record 26 of Set 11 | tuxpan
# Processing Record 27 of Set 11 | jardim
# Processing Record 28 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 11 | acarau
# Processing Record 30 of Set 11 | gambissara
# Processing Record 31 of Set 11 | sfantu gheorghe
# Processing Record 32 of Set 11 | qinzhou
# Processing Record 33 of Set 11 | palmer
# Processing Record 34 of Set 11 | port macquarie
# Processing Record 35 of Set 11 | beliu
# Processing Record 36 of Set 11 | huejucar
# Processing Record 37 of Set 11 | wuda
# Processing Record 38 of Set 11 | dobric
# Processing Record 39 of Set 11 | shuyskoye
# Processing Record 40 of Set 11 | rapar
# Processing Record 41 of Set 11 | rio gallegos
# Processing Record 42 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 43 of Set 11 | bubaque
# Processing Record 44 of Set 11 | adrar
# Processing Record 45 of Set 11 | puerto madryn
# Processing Record 46 of Set 11 | nanortalik
# Processing Record 47 of Set 11 | kasongo-lunda
# Processing Record 48 of Set 11 | payakumbuh
# Processing Record 49 of Set 11 | kyrnasivka
# Processing Record 50 of Set 11 | kargasok
# Processing Record 1 of Set 12 | orlik
# Processing Record 2 of Set 12 | buy
# Processing Record 3 of Set 12 | yulara
# Processing Record 4 of Set 12 | vanimo
# Processing Record 5 of Set 12 | santa pola
# Processing Record 6 of Set 12 | mikhaylovka
# Processing Record 7 of Set 12 | ruteng
# Processing Record 8 of Set 12 | miri
# Processing Record 9 of Set 12 | carlsbad
# Processing Record 10 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 11 of Set 12 | guadalupe y calvo
# Processing Record 12 of Set 12 | chhatarpur
# Processing Record 13 of Set 12 | codrington
# Processing Record 14 of Set 12 | pangnirtung
# Processing Record 15 of Set 12 | dubbo
# Processing Record 16 of Set 12 | pemangkat
# Processing Record 17 of Set 12 | griffith
# Processing Record 18 of Set 12 | bonavista
# Processing Record 19 of Set 12 | tayu
# Processing Record 20 of Set 12 | viedma
# Processing Record 21 of Set 12 | ossora
# Processing Record 22 of Set 12 | karsava
# Processing Record 23 of Set 12 | weinan
# Processing Record 24 of Set 12 | campoverde
# Processing Record 25 of Set 12 | port hardy
# Processing Record 26 of Set 12 | pacific grove
# Processing Record 27 of Set 12 | imeni poliny osipenko
# Processing Record 28 of Set 12 | lindsay
# Processing Record 29 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 12 | sisimiut
# Processing Record 31 of Set 12 | lubango
# Processing Record 32 of Set 12 | jiayuguan
# Processing Record 33 of Set 12 | qabis
# City not found. Skipping...
# Processing Record 34 of Set 12 | chamalieres
# Processing Record 35 of Set 12 | makanya
# Processing Record 36 of Set 12 | miranda
# Processing Record 37 of Set 12 | potsdam
# Processing Record 38 of Set 12 | jieshi
# Processing Record 39 of Set 12 | gaozhou
# Processing Record 40 of Set 12 | edissiya
# Processing Record 41 of Set 12 | aden
# Processing Record 42 of Set 12 | zhelyabovka
# Processing Record 43 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 44 of Set 12 | sistranda
# Processing Record 45 of Set 12 | menongue
# Processing Record 46 of Set 12 | lugovoy
# Processing Record 47 of Set 12 | alice springs
# Processing Record 48 of Set 12 | phrai bung
# City not found. Skipping...
# Processing Record 49 of Set 12 | knysna
# Processing Record 50 of Set 12 | tiberias
# Processing Record 1 of Set 13 | urumqi
# Processing Record 2 of Set 13 | mackenzie
# Processing Record 3 of Set 13 | kiboga
# Processing Record 4 of Set 13 | vila do maio
# Processing Record 5 of Set 13 | ayagoz
# Processing Record 6 of Set 13 | nsanje
# Processing Record 7 of Set 13 | hermiston
# Processing Record 8 of Set 13 | sao felix do xingu
# Processing Record 9 of Set 13 | micheweni
# Processing Record 10 of Set 13 | bowling green
# Processing Record 11 of Set 13 | synya
# Processing Record 12 of Set 13 | moinesti
# Processing Record 13 of Set 13 | mbala
# Processing Record 14 of Set 13 | hillsborough
# Processing Record 15 of Set 13 | oranjestad
# Processing Record 16 of Set 13 | raga
# Processing Record 17 of Set 13 | ashcroft
# Processing Record 18 of Set 13 | nyanguge
# Processing Record 19 of Set 13 | san ramon
# Processing Record 20 of Set 13 | sumbawanga
# Processing Record 21 of Set 13 | chokurdakh
# Processing Record 22 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 13 | cap malheureux
# Processing Record 24 of Set 13 | sile
# Processing Record 25 of Set 13 | agucadoura
# Processing Record 26 of Set 13 | pangai
# Processing Record 27 of Set 13 | sovetskiy
# Processing Record 28 of Set 13 | corrente
# Processing Record 29 of Set 13 | peniche
# Processing Record 30 of Set 13 | kazanskoye
# Processing Record 31 of Set 13 | palu
# Processing Record 32 of Set 13 | minervino murge
# Processing Record 33 of Set 13 | okakarara
# Processing Record 34 of Set 13 | bosaso
# Processing Record 35 of Set 13 | luderitz
# Processing Record 36 of Set 13 | santa rosa
# Processing Record 37 of Set 13 | namatanai
# Processing Record 38 of Set 13 | kushiro
# Processing Record 39 of Set 13 | shizunai
# Processing Record 40 of Set 13 | carbonear
# Processing Record 41 of Set 13 | payyannur
# Processing Record 42 of Set 13 | boralday
# Processing Record 43 of Set 13 | adamovka
# Processing Record 44 of Set 13 | manubah
# City not found. Skipping...
# Processing Record 45 of Set 13 | yenagoa
# Processing Record 46 of Set 13 | rurrenabaque
# Processing Record 47 of Set 13 | la paz
# Processing Record 48 of Set 13 | halifax
# Processing Record 49 of Set 13 | abu dhabi
# Processing Record 50 of Set 13 | laem sing
# Processing Record 1 of Set 14 | payo
# Processing Record 2 of Set 14 | heyang
# Processing Record 3 of Set 14 | richards bay
# Processing Record 4 of Set 14 | kothen
# Processing Record 5 of Set 14 | buraydah
# Processing Record 6 of Set 14 | yarmouth
# Processing Record 7 of Set 14 | basoko
# Processing Record 8 of Set 14 | okhotsk
# Processing Record 9 of Set 14 | minsk
# Processing Record 10 of Set 14 | bardiyah
# Processing Record 11 of Set 14 | luganville
# Processing Record 12 of Set 14 | pogar
# Processing Record 13 of Set 14 | garwa
# Processing Record 14 of Set 14 | zapolyarnyy
# Processing Record 15 of Set 14 | arman
# Processing Record 16 of Set 14 | miyako
# Processing Record 17 of Set 14 | krasne
# Processing Record 18 of Set 14 | igrim
# Processing Record 19 of Set 14 | buchanan
# Processing Record 20 of Set 14 | dubti
# Processing Record 21 of Set 14 | kidal
# Processing Record 22 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 24 of Set 14 | buta
# Processing Record 25 of Set 14 | valparaiso
# Processing Record 26 of Set 14 | neiafu
# Processing Record 27 of Set 14 | yingshang
# City not found. Skipping...
# Processing Record 28 of Set 14 | atambua
# Processing Record 29 of Set 14 | hay river
# Processing Record 30 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 31 of Set 14 | houston
# Processing Record 32 of Set 14 | slavsk
# Processing Record 33 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 34 of Set 14 | huarmey
# Processing Record 35 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 14 | bunbury
# Processing Record 37 of Set 14 | dalvik
# Processing Record 38 of Set 14 | puerto narino
# Processing Record 39 of Set 14 | gari
# Processing Record 40 of Set 14 | foumban
# Processing Record 41 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 14 | salair
# Processing Record 43 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 14 | dukat
# Processing Record 45 of Set 14 | lishui
# Processing Record 46 of Set 14 | sztum
# Processing Record 47 of Set 14 | swan hill
# Processing Record 48 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 14 | rudbar
# Processing Record 50 of Set 14 | rafai
# Processing Record 1 of Set 15 | ardakan
# Processing Record 2 of Set 15 | santa cruz
# Processing Record 3 of Set 15 | tokat
# Processing Record 4 of Set 15 | hualmay
# Processing Record 5 of Set 15 | marystown
# Processing Record 6 of Set 15 | uruzgan
# Processing Record 7 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 15 | stendal
# Processing Record 9 of Set 15 | puerto del rosario
# Processing Record 10 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 15 | bada
# Processing Record 12 of Set 15 | ximei
# Processing Record 13 of Set 15 | yayva
# Processing Record 14 of Set 15 | qena
# Processing Record 15 of Set 15 | palmas
# Processing Record 16 of Set 15 | luwuk
# Processing Record 17 of Set 15 | kintampo
# Processing Record 18 of Set 15 | sale
# Processing Record 19 of Set 15 | veraval
# Processing Record 20 of Set 15 | elmadag
# Processing Record 21 of Set 15 | bayangol
# Processing Record 22 of Set 15 | noyabrsk
# Processing Record 23 of Set 15 | nisia floresta
# Processing Record 24 of Set 15 | big rapids
# Processing Record 25 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 15 | coolum beach
# Processing Record 27 of Set 15 | northam
# Processing Record 28 of Set 15 | grand gaube
# Processing Record 29 of Set 15 | roma
# Processing Record 30 of Set 15 | muswellbrook
# Processing Record 31 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 33 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 15 | chakrata
# Processing Record 35 of Set 15 | chengde
# Processing Record 36 of Set 15 | cayenne
# Processing Record 37 of Set 15 | donetsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Victoria      HK  22.2855  114.1577     91.26        77          93
# 1      Shingu      JP  33.7333  135.9833     83.34        64         100
# 2  The Valley      AI  18.2170  -63.0578     82.26        74         100
# 3    Honolulu      US  21.3069 -157.8583     84.02        75          75
# 4    Imbituba      BR -28.2400  -48.6703     62.85        83          21
# 5       Tiksi      RU  71.6872  128.8694     41.04        89          93
# 6     Rikitea      PF -23.1203 -134.9692     69.98        81          89
# 7        Nome      US  64.5011 -165.4064     66.16        72           0
# 8        Hami      CN  42.8000   93.4500     83.73        23          47
# 9      Hobart      AU -42.8794  147.3294     50.25        79          75
#
#    Wind Speed Current Description
# 0        3.00     overcast clouds
# 1        2.30          light rain
# 2       20.80     overcast clouds
# 3       21.85       broken clouds
# 4        7.00          few clouds
# 5        8.08     overcast clouds
# 6        8.01          light rain
# 7       12.66           clear sky
# 8        8.59    scattered clouds
# 9       11.50       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
